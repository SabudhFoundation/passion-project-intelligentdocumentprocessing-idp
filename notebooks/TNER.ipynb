# %% [markdown]
# ### Setup

# %%
# main package
# %pip install tner -U
# %pip list | grep tner

# %%
import logging
from tner import GridSearcher, TransformersNER

logging.basicConfig(format='%(asctime)s %(levelname)-8s %(message)s', level=logging.INFO, datefmt='%Y-%m-%d %H:%M:%S')
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Finetuning
# Let's finetune `albert-base-v1` on `wnut2017`!

# %%
searcher = GridSearcher(
   checkpoint_dir='./ckpt_bert_wnut2017',
   dataset="tner/wnut2017",  # either of `dataset` (huggingface dataset) or `local_dataset` (custom dataset) should be given
   model="distilbert-base-cased",  # language model to fine-tune
   epoch=10,  # the total epoch (`L` in the figure)
   epoch_partial=5,  # the number of epoch at 1st stage (`M` in the figure)
   n_max_config=1,  # the number of models to pass to 2nd stage (`K` in the figure)
   batch_size=32,
   gradient_accumulation_steps=[2],
   crf=[True],
   lr=[1e-3, 1e-4],
   weight_decay=[None],
   random_seed=[42],
   lr_warmup_step_ratio=[0.1],
   max_grad_norm=[None, 10]
)
searcher.train()
# Out:
# INFO:root:INITIALIZE GRID SEARCHER: 4 configs to try
# INFO:root:## 1st RUN: Configuration 0/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/wnut2017
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: distilbert-base-cased
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `distilbert-base-cased`
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 2395
# INFO:root:preprocessed feature is saved at ./ckpt_bert_wnut2017/model_udaxih/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 802.07, lr: 0.0006756756756756757
# INFO:root:[epoch 0/10] average loss: 656.16, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 355.73, lr: 0.000924924924924925
# INFO:root:[epoch 1/10] average loss: 348.25, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 328.75, lr: 0.0008138138138138138
# INFO:root:[epoch 2/10] average loss: 336.69, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 329.11, lr: 0.0007027027027027027
# INFO:root:[epoch 3/10] average loss: 338.52, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 336.96, lr: 0.0005915915915915916
# INFO:root:[epoch 4/10] average loss: 338.22, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_udaxih/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_udaxih/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_wnut2017/model_udaxih
# INFO:root:## 1st RUN: Configuration 1/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/wnut2017
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: distilbert-base-cased
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `distilbert-base-cased`
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 2395
# INFO:root:preprocessed feature is saved at ./ckpt_bert_wnut2017/model_hexdvx/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 691.5, lr: 0.0006756756756756757
# INFO:root:[epoch 0/10] average loss: 787.77, lr: 0.001
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 350.82, lr: 0.000924924924924925
# INFO:root:[epoch 1/10] average loss: 335.86, lr: 0.0008888888888888888
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 312.19, lr: 0.0008138138138138138
# INFO:root:[epoch 2/10] average loss: 319.88, lr: 0.0007777777777777778
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 308.97, lr: 0.0007027027027027027
# INFO:root:[epoch 3/10] average loss: 316.42, lr: 0.0006666666666666666
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 309.64, lr: 0.0005915915915915916
# INFO:root:[epoch 4/10] average loss: 308.81, lr: 0.0005555555555555556
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_hexdvx/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_hexdvx/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_wnut2017/model_hexdvx
# INFO:root:## 1st RUN: Configuration 2/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/wnut2017
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: distilbert-base-cased
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: None
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `distilbert-base-cased`
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 2395
# INFO:root:preprocessed feature is saved at ./ckpt_bert_wnut2017/model_rcsnba/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 1198.31, lr: 6.756756756756757e-05
# INFO:root:[epoch 0/10] average loss: 915.27, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 304.13, lr: 9.24924924924925e-05
# INFO:root:[epoch 1/10] average loss: 294.9, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 227.6, lr: 8.138138138138138e-05
# INFO:root:[epoch 2/10] average loss: 227.15, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 176.89, lr: 7.027027027027028e-05
# INFO:root:[epoch 3/10] average loss: 183.35, lr: 6.666666666666667e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 148.28, lr: 5.915915915915916e-05
# INFO:root:[epoch 4/10] average loss: 142.02, lr: 5.555555555555556e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_rcsnba/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_rcsnba/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_wnut2017/model_rcsnba
# INFO:root:## 1st RUN: Configuration 3/4 ##
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/wnut2017
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: distilbert-base-cased
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# INFO:root:initialize language model with `distilbert-base-cased`
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForTokenClassification: ['vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForTokenClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# INFO:root:use CRF
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# INFO:root:dataset preprocessing
# INFO:root:encode all the data: 2395
# INFO:root:preprocessed feature is saved at ./ckpt_bert_wnut2017/model_cghqta/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 1194.94, lr: 6.756756756756757e-05
# INFO:root:[epoch 0/10] average loss: 899.59, lr: 0.0001
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_1
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_1
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_1
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.1.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 220.9, lr: 9.24924924924925e-05
# INFO:root:[epoch 1/10] average loss: 207.97, lr: 8.888888888888889e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_2
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_2
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_2
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.2.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 144.75, lr: 8.138138138138138e-05
# INFO:root:[epoch 2/10] average loss: 146.06, lr: 7.777777777777778e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_3
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_3
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_3
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.3.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 109.25, lr: 7.027027027027028e-05
# INFO:root:[epoch 3/10] average loss: 108.35, lr: 6.666666666666667e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_4
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_4
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_4
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.4.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 73.1, lr: 5.915915915915916e-05
# INFO:root:[epoch 4/10] average loss: 72.06, lr: 5.555555555555556e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.5.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_wnut2017/model_cghqta
# INFO:root:## 1st RUN (EVAL): Configuration 0/4 ##
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_udaxih/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:encode all the data: 1009
# INFO:root:preprocessed feature is saved at ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.74it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.00      0.00      0.00        34
#        group       0.00      0.00      0.00        39
#     location       0.00      0.00      0.00        74
#       person       0.00      0.00      0.00       470
#      product       0.00      0.00      0.00       114
#  work_of_art       0.00      0.00      0.00       105
#
#    micro avg       0.00      0.00      0.00       836
#    macro avg       0.00      0.00      0.00       836
# weighted avg       0.00      0.00      0.00       836
#
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# INFO:root:## 1st RUN (EVAL): Configuration 1/4 ##
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_hexdvx/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.79it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.00      0.00      0.00        34
#        group       0.00      0.00      0.00        39
#     location       0.00      0.00      0.00        74
#       person       0.00      0.00      0.00       470
#      product       0.00      0.00      0.00       114
#  work_of_art       0.00      0.00      0.00       105
#
#    micro avg       0.00      0.00      0.00       836
#    macro avg       0.00      0.00      0.00       836
# weighted avg       0.00      0.00      0.00       836
#
# INFO:root:## 1st RUN (EVAL): Configuration 2/4 ##
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_rcsnba/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.78it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.00      0.00      0.00        34
#        group       0.00      0.00      0.00        39
#     location       0.26      0.20      0.23        74
#       person       0.52      0.60      0.56       470
#      product       0.00      0.00      0.00       114
#  work_of_art       0.00      0.00      0.00       105
#
#    micro avg       0.49      0.36      0.41       836
#    macro avg       0.13      0.13      0.13       836
# weighted avg       0.31      0.36      0.33       836
#
# INFO:root:## 1st RUN (EVAL): Configuration 3/4 ##
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.81it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.21      0.21      0.21        34
#        group       0.28      0.13      0.18        39
#     location       0.63      0.57      0.60        74
#       person       0.79      0.51      0.62       470
#      product       0.37      0.13      0.19       114
#  work_of_art       0.21      0.06      0.09       105
#
#    micro avg       0.64      0.38      0.47       836
#    macro avg       0.41      0.27      0.31       836
# weighted avg       0.60      0.38      0.46       836
#
# INFO:root:1st RUN RESULTS
# INFO:root:	 * rank: 0 | metric: 0.474 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_5 |
# INFO:root:	 * rank: 1 | metric: 0.413 | model: ./ckpt_bert_wnut2017/model_rcsnba/epoch_5 |
# INFO:root:	 * rank: 2 | metric: 0.0 | model: ./ckpt_bert_wnut2017/model_udaxih/epoch_5 |
# INFO:root:	 * rank: 3 | metric: 0.0 | model: ./ckpt_bert_wnut2017/model_hexdvx/epoch_5 |
# INFO:root:## 2nd RUN: Configuration 0/1: 0.47439759036144585
# INFO:root:load checkpoint from ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_5`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:root:config is overwritten by ./ckpt_bert_wnut2017/model_cghqta/epoch_5
# INFO:root:hyperparameters
# INFO:root:	 * dataset: tner/wnut2017
# INFO:root:	 * dataset_split: train
# INFO:root:	 * dataset_name: None
# INFO:root:	 * local_dataset: None
# INFO:root:	 * model: distilbert-base-cased
# INFO:root:	 * crf: True
# INFO:root:	 * max_length: 128
# INFO:root:	 * epoch: 10
# INFO:root:	 * batch_size: 32
# INFO:root:	 * lr: 0.0001
# INFO:root:	 * random_seed: 42
# INFO:root:	 * gradient_accumulation_steps: 2
# INFO:root:	 * weight_decay: None
# INFO:root:	 * lr_warmup_step_ratio: 0.1
# INFO:root:	 * max_grad_norm: 10
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:dataset preprocessing
# INFO:root:load optimizer from ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.5.pt
# INFO:root:optimizer is loading on cuda
# INFO:root:load scheduler from ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.5.pt
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/model_cghqta/cache/encoded_feature.pkl
# INFO:root:start model training
# INFO:root:	 * global step 50: loss: 56.72, lr: 4.804804804804805e-05
# INFO:root:[epoch 5/10] average loss: 54.62, lr: 4.4444444444444447e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_6
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_6
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_6
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.6.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 46.09, lr: 3.693693693693694e-05
# INFO:root:[epoch 6/10] average loss: 38.92, lr: 3.3333333333333335e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_7
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_7
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_7
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.7.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 28.71, lr: 2.582582582582583e-05
# INFO:root:[epoch 7/10] average loss: 31.15, lr: 2.2222222222222223e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_8
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_8
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_8
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.8.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 21.07, lr: 1.4714714714714713e-05
# INFO:root:[epoch 8/10] average loss: 21.57, lr: 1.1111111111111112e-05
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_9
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_9
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_9
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.9.pt
# INFO:root:remove old optimizer files
# INFO:root:	 * global step 50: loss: 21.13, lr: 3.603603603603604e-06
# INFO:root:[epoch 9/10] average loss: 18.62, lr: 0.0
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.10.pt
# INFO:root:remove old optimizer files
# INFO:root:model saving at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:saving model weight at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:saving tokenizer at ./ckpt_bert_wnut2017/model_cghqta/epoch_10
# INFO:root:optimizer saving at ./ckpt_bert_wnut2017/model_cghqta/optimizers/optimizer.10.pt
# INFO:root:remove old optimizer files
# INFO:root:complete training: model ckpt was saved at ./ckpt_bert_wnut2017/model_cghqta
# INFO:root:## 2nd RUN (EVAL): Configuration 0/1 ##
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_1`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.75it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.00      0.00      0.00        34
#        group       0.00      0.00      0.00        39
#     location       0.00      0.00      0.00        74
#       person       0.00      0.00      0.00       470
#      product       0.00      0.00      0.00       114
#  work_of_art       0.00      0.00      0.00       105
#
#    micro avg       0.00      0.00      0.00       836
#    macro avg       0.00      0.00      0.00       836
# weighted avg       0.00      0.00      0.00       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_10`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:11<00:00,  5.80it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.18      0.21      0.19        34
#        group       0.18      0.08      0.11        39
#     location       0.65      0.58      0.61        74
#       person       0.76      0.55      0.64       470
#      product       0.32      0.19      0.24       114
#  work_of_art       0.20      0.12      0.15       105
#
#    micro avg       0.58      0.42      0.49       836
#    macro avg       0.38      0.29      0.32       836
# weighted avg       0.57      0.42      0.48       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_2`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# ...
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.17      0.26      0.21        34
#        group       0.11      0.08      0.09        39
#     location       0.48      0.59      0.53        74
#       person       0.79      0.43      0.56       470
#      product       0.67      0.04      0.07       114
#  work_of_art       0.00      0.00      0.00       105
#
#    micro avg       0.61      0.31      0.41       836
#    macro avg       0.37      0.23      0.24       836
# weighted avg       0.59      0.31      0.38       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_6`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:10<00:00,  5.82it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.13      0.18      0.15        34
#        group       0.09      0.03      0.04        39
#     location       0.51      0.54      0.52        74
#       person       0.80      0.53      0.64       470
#      product       0.33      0.25      0.29       114
#  work_of_art       0.28      0.09      0.13       105
#
#    micro avg       0.59      0.40      0.48       836
#    macro avg       0.36      0.27      0.29       836
# weighted avg       0.58      0.40      0.47       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_7`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:10<00:00,  5.82it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.18      0.32      0.23        34
#        group       0.10      0.08      0.09        39
#     location       0.66      0.53      0.59        74
#       person       0.78      0.51      0.62       470
#      product       0.34      0.22      0.27       114
#  work_of_art       0.23      0.08      0.11       105
#
#    micro avg       0.58      0.39      0.47       836
#    macro avg       0.38      0.29      0.32       836
# weighted avg       0.59      0.39      0.46       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_8`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:12<00:00,  5.10it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.20      0.26      0.23        34
#        group       0.13      0.10      0.11        39
#     location       0.62      0.57      0.59        74
#       person       0.76      0.52      0.62       470
#      product       0.34      0.24      0.28       114
#  work_of_art       0.23      0.11      0.15       105
#
#    micro avg       0.57      0.41      0.47       836
#    macro avg       0.38      0.30      0.33       836
# weighted avg       0.57      0.41      0.47       836
#
# INFO:root:initialize language model with `./ckpt_bert_wnut2017/model_cghqta/epoch_9`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:loading preprocessed feature from ./ckpt_bert_wnut2017/encoded/distilbert-base-cased.128.dev.True.validation.pkl
# 100%|██████████| 64/64 [00:10<00:00,  5.82it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.21      0.21      0.21        34
#        group       0.14      0.08      0.10        39
#     location       0.61      0.57      0.59        74
#       person       0.73      0.58      0.65       470
#      product       0.43      0.13      0.20       114
#  work_of_art       0.25      0.12      0.17       105
#
#    micro avg       0.60      0.42      0.50       836
#    macro avg       0.39      0.28      0.32       836
# weighted avg       0.57      0.42      0.48       836
#
# INFO:root:2nd RUN RESULTS:
# [('./ckpt_bert_wnut2017/model_cghqta/epoch_9', 0.49719101123595505), ('./ckpt_bert_wnut2017/model_cghqta/epoch_10', 0.48603351955307267), ('./ckpt_bert_wnut2017/model_cghqta/epoch_6', 0.47727272727272724), ('./ckpt_bert_wnut2017/model_cghqta/epoch_5', 0.47439759036144585), ('./ckpt_bert_wnut2017/model_cghqta/epoch_8', 0.4728033472803347), ('./ckpt_bert_wnut2017/model_cghqta/epoch_7', 0.46538187009279086), ('./ckpt_bert_wnut2017/model_cghqta/epoch_4', 0.4119968429360694), ('./ckpt_bert_wnut2017/model_cghqta/epoch_3', 0.3993260320134793), ('./ckpt_bert_wnut2017/model_cghqta/epoch_2', 0.25607476635514015), ('./ckpt_bert_wnut2017/model_cghqta/epoch_1', 0.0)]
# INFO:root:	 * rank: 0 | metric: 0.497 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_9 |
# INFO:root:	 * rank: 1 | metric: 0.486 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_10 |
# INFO:root:	 * rank: 2 | metric: 0.477 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_6 |
# INFO:root:	 * rank: 3 | metric: 0.474 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_5 |
# INFO:root:	 * rank: 4 | metric: 0.473 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_8 |
# INFO:root:	 * rank: 5 | metric: 0.465 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_7 |
# INFO:root:	 * rank: 6 | metric: 0.412 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_4 |
# INFO:root:	 * rank: 7 | metric: 0.399 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_3 |
# INFO:root:	 * rank: 8 | metric: 0.256 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_2 |
# INFO:root:	 * rank: 9 | metric: 0.0 | model: ./ckpt_bert_wnut2017/model_cghqta/epoch_1 |

# %% [markdown]
# ### Evaluation
# Now the best model is stored at `ckpt_bert_wnut2017/best_model`, so let's load the model run evaluation on the test split.

# %% [markdown]
# First, we load the model and check the prediction.

# %%
model = TransformersNER("ckpt_bert_wnut2017/best_model")
model.predict(["Jacob Collier is a Grammy awarded English artist from London"])
# Out:
# INFO:root:initialize language model with `ckpt_bert_wnut2017/best_model`
# INFO:root:use CRF
# INFO:root:loading pre-trained CRF layer
# INFO:root:label2id: {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12}
# INFO:root:1 GPUs are in use
# INFO:root:encode all the data: 1
# 100%|██████████| 1/1 [00:00<00:00, 31.64it/s]
# {'prediction': [['B-person',
#    'I-person',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-location']],
#  'probability': [[0.9962937235832214,
#    0.9981454610824585,
#    0.9974803328514099,
#    0.9983426332473755,
#    0.988684356212616,
#    0.9980375170707703,
#    0.9840778112411499,
#    0.9986743927001953,
#    0.998393714427948,
#    0.987984836101532]],
#  'input': [['Jacob',
#    'Collier',
#    'is',
#    'a',
#    'Grammy',
#    'awarded',
#    'English',
#    'artist',
#    'from',
#    'London']],
#  'entity_prediction': [[{'type': 'person',
#     'entity': ['Jacob', 'Collier'],
#     'position': [0, 1],
#     'probability': [0.9962937235832214, 0.9981454610824585]},
#    {'type': 'location',
#     'entity': ['London'],
#     'position': [9],
#     'probability': [0.987984836101532]}]]}

# %% [markdown]
# Then, the model instance has `evaluate` function where one can run evaluatino on the dataset easily.

# %%
metric = model.evaluate('tner/wnut2017', dataset_split='test', batch_size=16)
# Out:
# WARNING:datasets.builder:Found cached dataset wnut2017 (/root/.cache/huggingface/datasets/tner___wnut2017/wnut2017/1.0.0/d5817c8a3dec4121a3eb34c841757246ca24030cd333b9ca060609f874c1c5b0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:root:concat_label2id is specified {'B-corporation': 0, 'B-creative-work': 1, 'B-group': 2, 'B-location': 3, 'B-person': 4, 'B-product': 5, 'I-corporation': 6, 'I-creative-work': 7, 'I-group': 8, 'I-location': 9, 'I-person': 10, 'I-product': 11, 'O': 12} but not changed as is only one dataset
# INFO:root:encode all the data: 1287
# 100%|██████████| 81/81 [00:13<00:00,  5.88it/s]
# INFO:root:map entity into shared label set {'location': ['LOCATION', 'LOC', 'location', 'Location'], 'organization': ['ORGANIZATION', 'ORG', 'organization'], 'person': ['PERSON', 'PSN', 'person', 'PER'], 'date': ['DATE', 'DAT', 'YEAR', 'Year'], 'time': ['TIME', 'TIM', 'Hours'], 'artifact': ['ARTIFACT', 'ART', 'artifact'], 'percent': ['PERCENT', 'PNT'], 'other': ['OTHER', 'MISC'], 'money': ['MONEY', 'MNY', 'Price'], 'corporation': ['corporation'], 'group': ['group', 'NORP'], 'product': ['product', 'PRODUCT'], 'rating': ['Rating', 'RATING'], 'amenity': ['Amenity'], 'restaurant': ['Restaurant_Name'], 'dish': ['Dish'], 'cuisine': ['Cuisine'], 'actor': ['ACTOR', 'Actor'], 'title': ['TITLE'], 'genre': ['GENRE', 'Genre'], 'director': ['DIRECTOR', 'Director'], 'song': ['SONG'], 'plot': ['PLOT', 'Plot'], 'review': ['REVIEW'], 'character': ['CHARACTER'], 'ratings_average': ['RATINGS_AVERAGE'], 'trailer': ['TRAILER'], 'opinion': ['Opinion'], 'award': ['Award'], 'origin': ['Origin'], 'soundtrack': ['Soundtrack'], 'relationship': ['Relationship'], 'character_name': ['Character_Name'], 'quote': ['Quote'], 'cardinal_number': ['CARDINAL'], 'ordinal_number': ['ORDINAL'], 'quantity': ['QUANTITY'], 'law': ['LAW'], 'geopolitical_area': ['GPE'], 'work_of_art': ['WORK_OF_ART', 'creative-work', 'creative_work'], 'facility': ['FAC'], 'language': ['LANGUAGE'], 'event': ['EVENT'], 'dna': ['DNA'], 'protein': ['protein'], 'cell_type': ['cell_type'], 'cell_line': ['cell_line'], 'rna': ['RNA'], 'chemical': ['Chemical'], 'disease': ['Disease']}
# INFO:root:
#               precision    recall  f1-score   support
#
#  corporation       0.16      0.14      0.15        66
#        group       0.48      0.09      0.15       165
#     location       0.51      0.40      0.45       150
#       person       0.73      0.44      0.55       429
#      product       0.26      0.08      0.12       127
#  work_of_art       0.31      0.11      0.17       142
#
#    micro avg       0.54      0.28      0.36      1079
#    macro avg       0.41      0.21      0.26      1079
# weighted avg       0.52      0.28      0.35      1079

# %%
metric
# Out:
# {'micro/f1': 0.36441717791411044,
#  'micro/f1_ci': {},
#  'micro/recall': 0.2752548656163114,
#  'micro/precision': 0.5390199637023594,
#  'macro/f1': 0.26342802275329885,
#  'macro/f1_ci': {},
#  'macro/recall': 0.2090977294980844,
#  'macro/precision': 0.4095949456340495,
#  'per_entity_metric': {'corporation': {'f1': 0.1475409836065574,
#    'f1_ci': {},
#    'precision': 0.16071428571428573,
#    'recall': 0.13636363636363635},
#   'group': {'f1': 0.15306122448979592,
#    'f1_ci': {},
#    'precision': 0.4838709677419355,
#    'recall': 0.09090909090909091},
#   'location': {'f1': 0.44776119402985076,
#    'f1_ci': {},
#    'precision': 0.5084745762711864,
#    'recall': 0.4},
#   'person': {'f1': 0.5451895043731779,
#    'f1_ci': {},
#    'precision': 0.7276264591439688,
#    'recall': 0.4358974358974359},
#   'product': {'f1': 0.12121212121212119,
#    'f1_ci': {},
#    'precision': 0.2631578947368421,
#    'recall': 0.07874015748031496},
#   'work_of_art': {'f1': 0.16580310880829016,
#    'f1_ci': {},
#    'precision': 0.3137254901960784,
#    'recall': 0.11267605633802817}}}
